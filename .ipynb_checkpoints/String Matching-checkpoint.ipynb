# %% [markdown]
# # String Matcher
# The idea is to match a string using a genetic algorithm. The model would basically learn what the string is through multiple generations.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import string
import itertools
import pandas as pd

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
class string_matcher:
        
    def __init__ (self, password, population_size, mutation_rate, best_survivors, total_survivors, length_max):
        self.password = password
        self.population_size = population_size
        self.best_survivors = best_survivors
        self.total_survivors = total_survivors
        self.length_max = length_max
        self.mutation_rate = mutation_rate
        
        self.best_individual = np.asarray(["abc", -0.01])
        self.gen_count = 0
        
        self.average_cost_array = np.asarray([])
        self.best_cost_array = np.asarray([])
        
        self.characters = string.ascii_letters + string.digits
        
        self.__generate_first_population()
        
    def make_child(self, parent_1, parent_2):
        longer_parent  = list(parent_1 if len(parent_1) > len(parent_2) else parent_2)
        shorter_parent = list(parent_2 if len(parent_1) > len(parent_2) else parent_1)
    
        child = longer_parent.copy()
        n = len(shorter_parent)
        i = 0
        while i < n:
            child[i] = random.choice(string.characters) if random.uniform(0, 1) > self.mutation_rate else child[i]
            
            if (i < len(shorter_parent)):
                child[i] = shorter_parent[i] if random.uniform(0, 1) > 0.5 else longer_parent[i]
            
            if(len(child) < self.length_max):
                if (random.uniform(0,1) > self.mutation_rate):
                    child.insert(i, random.choice(self.characters))
                    n+=1
                
            if (random.uniform(0,1) > self.mutation_rate):
                child.remove(child[i])
                n-=1
            i+=1
        return "".join(child)
    
    def evaluate_cost(self, actual, new):
        together = itertools.zip_longest(actual, new, fillvalue=None)
        cost = len([a for a,b in together if a == b])
        cost /= max(len(actual), len(new))
        return cost

    def string_gen(self, length):
        individual = "".join(random.choice(self.characters) for _ in range(length))
        return individual
    
    def display_generation(self):
        print(self.current_population)
        
    def __generate_first_population(self):
        population = []
        for _ in range(0,self.population_size):
            length = random.randint(1,self.length_max)
            individual = self.string_gen(length)
            population.append(individual)
        self.current_population = np.c_[np.asarray(population), np.zeros(len(population))]
        self.__generation_cost()
        self.__log_generation()
        self.gen_count = 1
        
    def __generation_cost(self):
        for i in range(0, len(self.current_population)):
            self.current_population[i][1] = self.evaluate_cost(self.password, self.current_population[i][0])
        self.current_population = self.current_population[self.current_population[:,1].argsort()[::-1]]
        if (self.current_population[0][1] > self.best_individual[1]):
            self.best_individual = self.current_population[0]
        
    def __select_to_breed(self):
        survivors = self.current_population[0:self.best_survivors].copy()
        random_ind = []
        for _ in range(0, (self.total_survivors - self.best_survivors)):
            random_ind.append(self.current_population[random.randint(self.best_survivors,len(self.current_population) - 1)])
        random_ind = np.asarray(random_ind)
        return np.r_[survivors, random_ind]
    
    def __log_generation(self):
        print("String: ", self.current_population[0][0], " Cost: ", self.current_population[0][1])
        self.average_cost_array = np.append(self.average_cost_array, self.current_population[:,1].ravel().astype(np.float).mean())
        self.best_cost_array = np.append(self.best_cost_array, self.current_population[0][1].astype(np.float))
        
    def plot_costs(self):
        plt.figure(figsize=(10,10))
        plt.plot(self.average_cost_array, label='Average Cost')
        plt.plot(self.best_cost_array, label='Best Cost')
        plt.legend(loc='lower right')
        plt.show()
    
    def __display_best_individual(self):        
        print("Best Individual in ", self.gen_count, " generations")
        print("String: ", self.best_individual[0], " Cost: ", self.best_individual[1])
        
    def __next_generation(self):
        parents = self.__select_to_breed()
        population = []
        for i in range(0, 10):
            for j in range(0, 10):
                population.append(self.make_child(parents[i][0], parents[j][0]))
        self.current_population = np.c_[np.asarray(population), np.zeros(len(population))]
        self.gen_count += 1
        self.__generation_cost()
        self.__log_generation()
    
    def run(self, epochs):
        for _ in range(0, epochs):
            self.__next_generation()
            if (self.best_individual[1].astype(np.float) == 1.0):
                break
        self.__display_best_individual()

# %%
mypwd = "ABCDEFGHIJKLMNOPQR5STU4VW3X2Y1Z"

# %%
matcher = string_matcher(password=mypwd, population_size=10000, best_survivors=70, total_survivors=100, mutation_rate=0.95, length_max=32)
# Out:
# String:  9sSSsDJ7sOgLRCOarE9TU82I8  Cost:  0.15384615384615385

# %%
matcher.run(1000)
# Out:
# String:  8fCwEF2h4yldQIOPQgd7sdnXIvFM6  Cost:  0.2413793103448276
# String:  AsV9EIGTnJoLQAO0Qed3Uu2XQ2IlvFM6  Cost:  0.28125
# String:  AsC9EFGTnJoLAAO0hdd3Ud2XIvvlvM6  Cost:  0.3225806451612903
# String:  AsC9EF5BnNgdAfOPhRSTUdrXYvIF9ii  Cost:  0.3870967741935484
# String:  ABCBEFkHnJlZMqOPPRShUdrXNvmFCC6  Cost:  0.45161290322580644
# String:  ABCIEFGHnJlZMAOQzhSTUArXYZIvvCi6  Cost:  0.5
# String:  ACCwEFH4lJoZMqOPQRSTUVNXYZCl6  Cost:  0.5862068965517241
# String:  ABCwEFHHeJLLMqOPQRSTUVrXYZIlvC6  Cost:  0.6451612903225806
# String:  ABCEEFGHlJoZMqOPQRSTUVrXYZCv96  Cost:  0.6666666666666666
# String:  ABCwEFGHJJoLMqOPQRSTUVEXYZvv66  Cost:  0.7
# String:  ABCEEFGHJJgLqqOPQRSTUVYXYZml  Cost:  0.7142857142857143
# String:  ABCwEFGHJJgLMqOPARSTUVYXYZm  Cost:  0.7407407407407407
# String:  ABCwEFGHJJLLMqOPARSTUVrXYZ  Cost:  0.7692307692307693
# String:  ABCBEFGHJJoLMqOPQSSTUVrXYZ  Cost:  0.7692307692307693
# String:  ABCwEFGHJJLLM3OPQRSTUVrXYZ6  Cost:  0.7777777777777778
# String:  ABCwEFGHJJLLMqOPQRSTUVrXYZZ  Cost:  0.7777777777777778
# String:  ABCEEFGHJJLLMqOPQRSTUVrXYZZ  Cost:  0.7777777777777778
# String:  ABCwEFGHJJLLMOOPQRSTUVrXYZ  Cost:  0.8076923076923077
# String:  ABCwEFGHFJLLMqOPQRSTUVXXYZ  Cost:  0.8076923076923077
# String:  ABCEEFGHIJLLMqOPQRSTUV9XYZ  Cost:  0.8461538461538461
# String:  ABCBEFGHIJLLMOOPQRSTUVXXYZZ  Cost:  0.8148148148148148
# String:  ABCEEFGHIJLLMqOPQRSTUVrXYZZ  Cost:  0.8148148148148148
# String:  ABCuEFGHIJLLMqOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCuEFGHIJLLMqOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCuEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCEEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMqOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMqOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMqOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMqOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMOOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJoLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJoLMOOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCzEFGHIJLLMOOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCfEFGHIJLLMOOPQRSTUVLXYZ  Cost:  0.8461538461538461
# String:  ABCfEFGHIJLLMOOPQRSTUVLXYZ  Cost:  0.8461538461538461
# String:  ABCdEFGHIJLLMOOPQRSTUVXXYZ  Cost:  0.8461538461538461
# String:  ABCEEFGHIJKMMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCfEFGHIJLLMOOPQRSTUVrXYZ  Cost:  0.8461538461538461
# String:  ABCEEFGHIJKLMwOPQRSTUVLXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMHOPQRSTUVLXYZ  Cost:  0.8846153846153846
# String:  ABCdEFGHIJKLMOOPQRSTUVXXYZZ  Cost:  0.8518518518518519
# String:  ABCEEFGHIJKLMsOPQRSTUVLXYZ  Cost:  0.8846153846153846
# String:  ABCdEFGHIJKLMOOPQRSTUVLXYZ  Cost:  0.8846153846153846
# String:  ABCdEFGHIJKLMOOPQRSTUVGXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMwOPQRSTUVAXYZ  Cost:  0.8846153846153846
# String:  ABCdEFGHIJKLMOOPQRSTUVGXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMOOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHJJKLMOOPQRSTUVsXYZ  Cost:  0.8461538461538461
# String:  ABCMEFGHIJKLMsOPQRSTUVsXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMOOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCDEFGHIJKLMOOPQRSTUVXXYZZ  Cost:  0.8888888888888888
# String:  ABCtEFGHIJKLMOOQQRSTUVsXYZ  Cost:  0.8461538461538461
# String:  ABCtEFGHIJKLMOOPQRSTUV5XYZZ  Cost:  0.8518518518518519
# String:  ABC9EFGHIJKLMOOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMOOPQRSTUVoXYZZ  Cost:  0.8518518518518519
# String:  ABC9EFGHIJKLMOOPQRSTUVXXYZZ  Cost:  0.8518518518518519
# String:  ABCEEFGHIJKLMOOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMOOPQRSTUVoXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMOOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABC5EFGHIJKLMyOPQRSTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMNOPQRSTUVXXYZZ  Cost:  0.8888888888888888
# String:  ABCEEFGHIJKLMNOPQRSTUVXXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRqTUVXXYZ  Cost:  0.8846153846153846
# String:  ABCEEFGHIJKLMNOPQRSTUVXXYZZ  Cost:  0.8888888888888888
# String:  ABCvEFGHIJKLMNOPQRSTUVXXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVXXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVYXYZ  Cost:  0.9230769230769231
# String:  ABCdEFGHIJKLMNOPQRSTUVXXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZ  Cost:  0.9230769230769231
# String:  BBCDEFGHIJKLMNOPQRSTUVSXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZZ  Cost:  0.8888888888888888
# String:  ABCiEFGHIJKLMNOPQRSTUVSXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZZ  Cost:  0.8888888888888888
# String:  ABCEEFGHIJKLMNOPQRSTUVSXYZZ  Cost:  0.8888888888888888
# String:  ABCuEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCFEFGHIJKLMNPPQRSTUVWXYZ  Cost:  0.9230769230769231
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCFEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCiEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC1EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC1EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC1EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC1EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC1EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCIEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEGGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9230769230769231
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCpEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCpEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCvEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCpEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCcEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCcEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCcEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC2EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCMEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABC8EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABC8EFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABClEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCkEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCcEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCqEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCzEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9259259259259259
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCeEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCEEFGHIJKLMNOPQRSTUVWXYZ  Cost:  0.9615384615384616
# String:  ABCDEFGHIJKLMNOPQRSTUVWXYZZ  Cost:  0.9629629629629629
# String:  ABCDEFGHIJKLMNOPQRSTUVWXYZ  Cost:  1.0
# Best Individual in  231  generations
# String:  ABCDEFGHIJKLMNOPQRSTUVWXYZ  Cost:  1.0

# %%
matcher.plot_costs()
